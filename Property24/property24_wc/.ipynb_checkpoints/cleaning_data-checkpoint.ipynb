# %%
import pandas as pd
# pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", 200)
# pd.options.display.max_rows = None


# pd.reset_option("display.max_rows")
# pd.reset_option("display.max_columns")

# %%
df = pd.read_json("property_details_wc.json")
df.head()
# Out:
#                                                  url        price  \
# 0  https://www.property24.com/new-developments-fo...         None
# 1  https://www.property24.com/new-developments/de...         None
# 2  https://www.property24.com/new-developments-fo...         None
# 3  https://www.property24.com/for-sale/val-de-vie...  R 6 600 000
# 4  https://www.property24.com/new-developments-fo...         None
#
#                                                 name  about_title  \
# 0                                               None          NaN
# 1                                               None          NaN
# 2                                               None          NaN
# 3  2 Bedroom Apartment / Flat for Sale in Val De ...          NaN
# 4                                               None          NaN
#
#                                                title  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Exquisite Ambrosia ground floor apartment in n...
# 4                                               None
#
#                                          description  Bedrooms  Bathrooms  \
# 0                                                          NaN        NaN
# 1                                                          NaN        NaN
# 2                                                          NaN        NaN
# 3  Val de Vie Properties exclusively presents thi...       2.0        2.0
# 4                                                          NaN        NaN
#
#    Parking Spaces Floor Size  ...  Special Features 17  Special Features 18  \
# 0             NaN        NaN  ...                  NaN                  NaN
# 1             NaN        NaN  ...                  NaN                  NaN
# 2             NaN        NaN  ...                  NaN                  NaN
# 3             1.0     104 m²  ...                  NaN                  NaN
# 4             NaN        NaN  ...                  NaN                  NaN
#
#    Special Features 19  Special Features 20 Pool 3  Outside Areas  \
# 0                  NaN                  NaN    NaN            NaN
# 1                  NaN                  NaN    NaN            NaN
# 2                  NaN                  NaN    NaN            NaN
# 3                  NaN                  NaN    NaN            NaN
# 4                  NaN                  NaN    NaN            NaN
#
#   Dining Room 4 Dining Room 5 Security 5 Outbuilding 8
# 0           NaN           NaN        NaN           NaN
# 1           NaN           NaN        NaN           NaN
# 2           NaN           NaN        NaN           NaN
# 3           NaN           NaN        NaN           NaN
# 4           NaN           NaN        NaN           NaN
#
# [5 rows x 349 columns]

# %%
df[df["price"].notnull()].isnull().sum()
# Out:
# url                  0
# price                0
# name                 0
# about_title      25044
# title                0
#                  ...
# Outside Areas    25043
# Dining Room 4    25043
# Dining Room 5    25043
# Security 5       25043
# Outbuilding 8    25043
# Length: 349, dtype: int64

# %%
df.dtypes
# Out:
# url               object
# price             object
# name              object
# about_title      float64
# title             object
#                   ...
# Outside Areas    float64
# Dining Room 4     object
# Dining Room 5     object
# Security 5        object
# Outbuilding 8     object
# Length: 349, dtype: object

# %%
df["Floor Size"].unique()
# Out:
# array([nan, '104 m²', '216 m²', '59 m²', '225 m²', '96 m²', '144 m²',
#        '214 m²', '245 m²', '146 m²', '314 m²', '54 m²', '358 m²',
#        '267 m²', '71 m²', '43 m²', '570 m²', '92 m²', '65 m²', '370 m²',
#        '107 m²', '339 m²', '98 m²', '87 m²', '233 m²', '82 m²', '99 m²',
#        '200 m²', '106 m²', '520 m²', '192 m²', '79 m²', '280 m²',
#        '340 m²', '162 m²', '139 m²', '479 m²', '42 m²', '240 m²',
#        '787 m²', '50 m²', '41 m²', '230 m²', '380 m²', '270 m²', '326 m²',
#        '374 m²', '648 m²', '221 m²', '145 m²', '122 m²', '373 m²',
#        '69 m²', '49 m²', '250 m²', '828 m²', '58 m²', '155 m²', '285 m²',
#        '252 m²', '86 m²', '222 m²', '117 m²', '264 m²', '105 m²',
#        '137 m²', '353 m²', '513 m²', '320 m²', '160 m²', '300 m²',
#        '166 m²', '679 m²', '505 m²', '172 m²', '156 m²', '210 m²',
#        '415 m²', '202 m²', '248 m²', '45 m²', '191 m²', '227 m²',
#        '130 m²', '175 m²', '31 m²', '57 m²', '126 m²', '111 m²', '283 m²',
#        '528 m²', '161 m²', '507 m²', '197 m²', '152 m²', '354 m²',
#        '150 m²', '319 m²', '90 m²', '46 m²', '47 m²', '176 m²', '665 m²',
#        '272 m²', '802 m²', '34 m²', '67 m²', '66 m²', '423 m²', '223 m²',
#        '360 m²', '195 m²', '110 m²', '70 m²', '246 m²', '880 m²',
#        '120 m²', '293 m²', '190 m²', '55 m²', '93 m²', '204 m²', '153 m²',
#        '97 m²', '35 m²', '268 m²', '112 m²', '189 m²', '64 m²', '74 m²',
#        '60 m²', '393 m²', '101 m²', '297 m²', '53 m²', '347 m²', '534 m²',
#        '61 m²', '208 m²', '89 m²', '294 m²', '184 m²', '325 m²', '163 m²',
#        '81 m²', '164 m²', '125 m²', '362 m²', '188 m²', '131 m²',
#        '241 m²', '595 m²', '182 m²', '85 m²', '310 m²', '577 m²',
#        '142 m²', '180 m²', '72 m²', '224 m²', '148 m²', '80 m²', '390 m²',
#        '500 m²', '199 m²', '255 m²', '76 m²', '78 m²', '127 m²', '382 m²',
#        '217 m²', '40 m²', '350 m²', '133 m²', '100 m²', '185 m²',
#        '141 m²', '158 m²', '26 m²', '95 m²', '219 m²', '183 m²', '271 m²',
#        '39 m²', '37 m²', '213 m²', '269 m²', '237 m²', '178 m²', '140 m²',
#        '282 m²', '102 m²', '157 m²', '109 m²', '170 m²', '590 m²',
#        '91 m²', '298 m²', '312 m²', '400 m²', '171 m²', '73 m²', '274 m²',
#        '187 m²', '129 m²', '375 m²', '167 m²', '446 m²', '38 m²',
#        '472 m²', '68 m²', '48 m²', '134 m²', '299 m²', '480 m²', '228 m²',
#        '115 m²', '84 m²', '342 m²', '62 m²', '292 m²', '332 m²', '476 m²',
#        '212 m²', '88 m²', '154 m²', '113 m²', '515 m²', '359 m²',
#        '181 m²', '25 m²', '495 m²', '56 m²', '151 m²', '463 m²', '318 m²',
#        '238 m²', '121 m²', '174 m²', '168 m²', '529 m²', '420 m²',
#        '218 m²', '434 m²', '220 m²', '211 m²', '311 m²', '522 m²',
#        '307 m²', '149 m²', '315 m²', '32 m²', '136 m²', '242 m²', '63 m²',
#        '209 m²', '118 m²', '231 m²', '75 m²', '369 m²', '290 m²',
#        '496 m²', '51 m²', '411 m²', '538 m²', '425 m²', '261 m²',
#        '376 m²', '119 m²', '244 m²', '281 m²', '258 m²', '179 m²',
#        '135 m²', '550 m²', '215 m²', '397 m²', '94 m²', '260 m²',
#        '251 m²', '30 m²', '186 m²', '103 m²', '108 m²', '138 m²', '83 m²',
#        '114 m²', '330 m²', '368 m²', '448 m²', '591 m²', '277 m²',
#        '177 m²', '322 m²', '289 m²', '235 m²', '494 m²', '694 m²',
#        '427 m²', '206 m²', '450 m²', '36 m²', '327 m²', '77 m²', '406 m²',
#        '650 m²', '132 m²', '201 m²', '169 m²', '492 m²', '333 m²',
#        '377 m²', '124 m²', '900 m²', '33 m²', '52 m²', '288 m²', '445 m²',
#        '173 m²', '29 m²', '304 m²', '165 m²', '469 m²', '485 m²',
#        '306 m²', '483 m²', '275 m²', '378 m²', '800 m²', '257 m²',
#        '713 m²', '193 m²', '44 m²', '198 m²', '335 m²', '1000 m²',
#        '287 m²', '226 m²', '295 m²', '232 m²', '385 m²', '207 m²',
#        '530 m²', '598 m²', '455 m²', '205 m²', '365 m²', '265 m²',
#        '334 m²', '196 m²', '116 m²', '418 m²', '486 m²', '128 m²',
#        '247 m²', '343 m²', '366 m²', '123 m²', '540 m²', '352 m²',
#        '147 m²', '653 m²', '405 m²', '229 m²', '262 m²', '324 m²',
#        '28 m²', '667 m²', '424 m²', '143 m²', '410 m²', '386 m²',
#        '573 m²', '309 m²', '259 m²', '194 m²', '680 m²', '608 m²',
#        '417 m²', '460 m²', '518 m²', '440 m²', '1004 m²', '429 m²',
#        '551 m²', '254 m²', '348 m²', '414 m²', '437 m²', '203 m²',
#        '431 m²', '620 m²', '498 m²', '392 m²', '655 m²', '556 m²',
#        '532 m²', '328 m²', '700 m²', '580 m²', '236 m²', '980 m²',
#        '303 m²', '279 m²', '439 m²', '554 m²', '331 m²', '1560 m²',
#        '1438 m²', '433 m²', '466 m²', '338 m²', '249 m²', '619 m²',
#        '159 m²', '256 m²', '470 m²', '481 m²', '1256 m²', '371 m²',
#        '2974 m²', '253 m²', '402 m²', '364 m²', '234 m²', '395 m²',
#        '291 m²', '239 m²', '681 m²', '284 m²', '305 m²', '381 m²',
#        '296 m²', '266 m²', '600 m²', '444 m²', '657 m²', '560 m²',
#        '527 m²', '503 m²', '1016 m²', '321 m²', '278 m²', '363 m²',
#        '567 m²', '442 m²', '457 m²', '533 m²', '404 m²', '372 m²',
#        '409 m²', '407 m²', '670 m²', '740 m²', '24 m²', '426 m²',
#        '516 m²', '27 m²', '344 m²', '1070 m²', '302 m²', '462 m²',
#        '263 m²', '323 m²', '361 m²', '430 m²', '512 m²', '785 m²',
#        '537 m²', '1340 m²', '850 m²', '408 m²', '759 m²', '341 m²',
#        '597 m²', '356 m²', '351 m²', '428 m²', '243 m²', '465 m²',
#        '1152 m²', '316 m²', '881 m²', '346 m²', '1452 m²', '20 m²',
#        '276 m²', '549 m²', '441 m²', '396 m²', '436 m²', '22 m²',
#        '475 m²', '301 m²', '399 m²', '419 m²', '313 m²', '660 m²',
#        '571 m²', '546 m²', '355 m²', '459 m²', '403 m²', '535 m²',
#        '379 m²', '468 m²', '478 m²', '387 m²', '23 m²', '412 m²',
#        '471 m²', '568 m²', '477 m²', '750 m²', '548 m²', '616 m²',
#        '630 m²', '572 m²', '729 m²', '273 m²', '517 m²', '384 m²',
#        '717 m²', '610 m²', '388 m²', '422 m²', '389 m²', '490 m²',
#        '626 m²', '357 m²', '714 m²', '416 m²', '1040 m²', '758 m²',
#        '647 m²', '367 m²', '345 m²', '413 m²', '394 m²', '499 m²',
#        '435 m²', '508 m²', '756 m²', '391 m²', '401 m²', '674 m²',
#        '691 m²', '1030 m²', '569 m²', '944 m²', '5192 m²', '575 m²',
#        '778 m²', '317 m²', '730 m²', '509 m²', '482 m²', '2000 m²',
#        '329 m²', '640 m²', '467 m²', '635 m²', '4253 m²', '559 m²',
#        '975 m²', '10185 m²', '607 m²', '2010 m²', '927 m²', '818 m²',
#        '708 m²', '7173 m²', '752 m²', '606 m²', '308 m²', '552 m²',
#        '1100 m²', '543 m²', '398 m²', '1238 m²', '1032 m²', '693 m²',
#        '336 m²', '4531 m²', '510 m²', '504 m²', '1429 m²', '484 m²',
#        '715 m²', '1196 m²', '666 m²', '860 m²', '690 m²', '834 m²',
#        '555 m²', '421 m²', '773 m²', '337 m²', '840 m²', '286 m²',
#        '497 m²', '780 m²', '808 m²', '506 m²', '553 m²', '734 m²',
#        '966 m²', '770 m²', '547 m²', '582 m²', '584 m²', '768 m²',
#        '618 m²', '558 m²', '636 m²', '525 m²', '521 m²', '443 m²',
#        '726 m²', '1250 m²', '456 m²', '1113 m²', '1159 m²', '19 m²',
#        '587 m²', '878 m²', '638 m²', '1022 m²', '1305 m²', '383 m²',
#        '1234 m²', '557 m²', '658 m²', '545 m²', '1550 m²', '1095 m²',
#        '877 m²', '1200 m²', '18 m²', '464 m²', '1020 m²', '562 m²',
#        '852 m²', '633 m²', '514 m²', '1450 m²', '1085 m²', '720 m²',
#        '592 m²', '565 m²', '656 m²', '760 m²', '458 m²', '676 m²',
#        '473 m²', '775 m²', '811 m²', '641 m²', '965 m²', '869 m²',
#        '672 m²', '735 m²', '1903 m²', '488 m²', '950 m²', '1180 m²',
#        '683 m²', '701 m²', '1385 m²', '438 m²', '697 m²', '876 m²',
#        '622 m²', '2106 m²', '6 m²', '21 m²', '585 m²', '447 m²', '502 m²',
#        '602 m²', '588 m²', '903 m²', '493 m²', '659 m²', '576 m²',
#        '736 m²', '541 m²', '696 m²', '1098 m²', '632 m²', '820 m²',
#        '888 m²', '1407 m²', '684 m²', '625 m²', '1255 m²', '754 m²',
#        '826 m²', '753 m²', '2013 m²', '15 m²', '604 m²', '1894 m²',
#        '862 m²', '1189 m²', '872 m²', '2030 m²', '1358 m²', '536 m²',
#        '1466 m²', '1050 m²', '1610 m²', '628 m²', '596 m²', '743 m²',
#        '2045 m²', '2080 m²', '859 m²', '970 m²', '92698 m²', '612 m²',
#        '432 m²', '451 m²', '487 m²', '452 m²', '454 m²', '671 m²',
#        '870 m²', '10 m²', '461 m²', '1090 m²', '791 m²', '449 m²',
#        '673 m²', '474 m²', '1120 m²', '1650 m²', '643 m²', '910 m²',
#        '491 m²', '611 m²', '1500 m²', '1 m²', '823 m²', '3300 m²',
#        '710 m²', '651 m²', '649 m²', '830 m²', '853 m²', '2739 m²',
#        '761 m²', '1626 m²', '644 m²', '739 m²', '1370 m²', '3180 m²',
#        '817 m²', '2 m²', '1800 m²', '890 m²', '1380 m²', '662 m²',
#        '1600 m²', '1080 m²', '686 m²', '742 m²', '856 m²', '645 m²',
#        '1674 m²', '976 m²'], dtype=object)

# %%
print(df["Floor Size"])
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3        104 m²
# 4           NaN
#           ...
# 25571    214 m²
# 25572    137 m²
# 25573       NaN
# 25574    170 m²
# 25575     65 m²
# Name: Floor Size, Length: 25576, dtype: object

# %%
df[df["price"]=="POA"]
# Out:
#                                                      url price  \
# 368    https://www.property24.com/for-sale/rondebosch...   POA
# 694    https://www.property24.com/for-sale/la-pinta-l...   POA
# 1152   https://www.property24.com/for-sale/thesen-isl...   POA
# 1153   https://www.property24.com/for-sale/camps-bay/...   POA
# 1154   https://www.property24.com/for-sale/camps-bay/...   POA
# ...                                                  ...   ...
# 25158  https://www.property24.com/for-sale/tulbagh/tu...   POA
# 25167  https://www.property24.com/for-sale/onrus/herm...   POA
# 25197  https://www.property24.com/for-sale/bloubergst...   POA
# 25421  https://www.property24.com/for-sale/sea-point/...   POA
# 25574  https://www.property24.com/for-sale/worcester-...   POA
#
#                                                     name  about_title  \
# 368    1 Bedroom Apartment / Flat On Auction in Ronde...          NaN
# 694    2 Bedroom House for Sale in La Pinta Lifestyle...          NaN
# 1152          2 Bedroom House for Sale in Thesen Islands          NaN
# 1153             5 Bedroom House On Auction in Camps Bay          NaN
# 1154             5 Bedroom House On Auction in Camps Bay          NaN
# ...                                                  ...          ...
# 25158              3 Bedroom House On Auction in Tulbagh          NaN
# 25167                  4 Bedroom House for Sale in Onrus          NaN
# 25197        10 Bedroom House for Sale in Bloubergstrand          NaN
# 25421              8 Bedroom House for Sale in Sea Point          NaN
# 25574         3 Bedroom House for Sale in Worcester West          NaN
#
#                                                    title  \
# 368                             Build Your Forever Home!
# 694    Coastal Elegance Awaits at La Pinta Lifestyle ...
# 1152                   2 Bedroom Apartment Thesen Island
# 1153   Prime Development Opportunity: 5 Bedroom Renov...
# 1154   Prime Development Opportunity: 5 Bedroom Renov...
# ...                                                  ...
# 25158  Deceased estate - 3 bedroom family home in tul...
# 25167  Discover potential in this prime Onrus  proper...
# 25197  *All offers will be considered* Luxurious 10+ ...
# 25421              Calling all investors and Developers!
# 25574               Plot and plan house in Secure Estate
#
#                                              description  Bedrooms  Bathrooms  \
# 368    ONLINE AUCTION Bidding Start Time: Wednesday 2...       1.0        1.0
# 694    Enjoy seamless ownership with transfer costs i...       2.0        2.5
# 1152   Sole & Exclusive Mandate This just listed a ge...       2.0        3.0
# 1153   Discover a remarkable development opportunity ...       5.0        2.0
# 1154   Discover a remarkable development opportunity ...       5.0        2.0
# ...                                                  ...       ...        ...
# 25158  AUCTION DETAILS Auction date: WEDNESDAY, 12 JU...       3.0        1.0
# 25167  Discover potential in this prime Onrus  proper...       4.0        3.0
# 25197  Welcome to this magnificent 10+ bedroom proper...      10.0        NaN
# 25421  Exclusive Sole Mandate! Backup offers welcome!...       8.0        8.0
# 25574  This home is yet to be built in Altona Village...       3.0        2.0
#
#        Parking Spaces Floor Size  ...  Special Features 17  \
# 368               1.0      46 m²  ...                  NaN
# 694               2.0     171 m²  ...                  NaN
# 1152              2.0     136 m²  ...                  NaN
# 1153              1.0        NaN  ...                  NaN
# 1154              1.0        NaN  ...                  NaN
# ...               ...        ...  ...                  ...
# 25158             NaN        NaN  ...                  NaN
# 25167             NaN     174 m²  ...                  NaN
# 25197             6.0     976 m²  ...                  NaN
# 25421             1.0        NaN  ...                  NaN
# 25574             2.0     170 m²  ...                  NaN
#
#        Special Features 18  Special Features 19  Special Features 20 Pool 3  \
# 368                    NaN                  NaN                  NaN    NaN
# 694                    NaN                  NaN                  NaN    NaN
# 1152                   NaN                  NaN                  NaN    NaN
# 1153                   NaN                  NaN                  NaN    NaN
# 1154                   NaN                  NaN                  NaN    NaN
# ...                    ...                  ...                  ...    ...
# 25158                  NaN                  NaN                  NaN    NaN
# 25167                  NaN                  NaN                  NaN    NaN
# 25197                  NaN                  NaN                  NaN    NaN
# 25421                  NaN                  NaN                  NaN    NaN
# 25574                  NaN                  NaN                  NaN    NaN
#
#        Outside Areas Dining Room 4 Dining Room 5 Security 5 Outbuilding 8
# 368              NaN           NaN           NaN        NaN           NaN
# 694              NaN           NaN           NaN        NaN           NaN
# 1152             NaN           NaN           NaN        NaN           NaN
# 1153             NaN           NaN           NaN        NaN           NaN
# 1154             NaN           NaN           NaN        NaN           NaN
# ...              ...           ...           ...        ...           ...
# 25158            NaN           NaN           NaN        NaN           NaN
# 25167            NaN           NaN           NaN        NaN           NaN
# 25197            NaN           NaN           NaN        NaN           NaN
# 25421            NaN           NaN           NaN        NaN           NaN
# 25574            NaN           NaN           NaN        NaN           NaN
#
# [184 rows x 349 columns]

# %%
a=6
